# %% [markdown]
# #A simple pyfits example
#
# Here is a very quick example to get you started with using pyfits

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import pyfits

# %% [markdown]
# It's very simple to read in data from fits files.

# %%
data = pyfits.getdata('606s_775_1.fits') # data is a numpy array
data
# Out:
# array([[-0.00513811,  0.00538263,  0.00354558, ..., -0.00298278,
#          0.00248811, -0.00379359],
#        [ 0.00238521,  0.00344998,  0.00084735, ..., -0.00167213,
#          0.00506442,  0.00135151],
#        [ 0.00479849,  0.00726841, -0.00504038, ..., -0.00088157,
#         -0.00248802, -0.00046302],
#        ...,
#        [-0.00672347, -0.00399758,  0.00426744, ...,  0.0038842 ,
#         -0.0014339 , -0.00502297],
#        [ 0.00297757, -0.00075421, -0.0036631 , ..., -0.00199271,
#         -0.00020651,  0.00062165],
#        [-0.0032452 , -0.00077249, -0.00049254, ..., -0.00270407,
#         -0.00084796, -0.00076966]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Here's how you might display an image you have read in.

# %%
plt.imshow(data, cmap=plt.cm.gray)

# %% [markdown]
# You can read in the fits header

# %%
hdr = pyfits.getheader('606s_775_1.fits')

# %%
print hdr
# Out:
# SIMPLE  =                    T / Written by IDL:  Tue Oct  8 20:40:49 2013
# BITPIX  =                   32 / Number of bits per data pixel
# NAXIS   =                    0 / Number of data axes
# EXTEND  =                    T / FITS data may contain extensions
# DATE    = '2013-10-08'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# NOBJ    =                  200 /
# ZPT     =        25.6790000000 /

# %% [markdown]
# And here's how to write to a file.

# %%
pyfits.writeto("temp2.fits", data, header=hdr)
